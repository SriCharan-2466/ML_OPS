# %%
# !pip install mlflow dagshub scikit-learn pandas matplotlib -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 98.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 91.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.3/273.3 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.8/148.8 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 13.8 MB/s eta 0:00:00
# ...

# %%
# !git config --global user.name "SriCharan-2466"
# !git config --global user.email deshamonisricharan@gmail.com

# %%
# !git config --global --list
# Out:
# user.name=SriCharan-2466
# user.email=deshamonisricharan@gmail.com

# %%
TOKEN="81146a5cda5087eafbfc9c9a00a0e2b228f97e62"
# !git clone https://$TOKEN@dagshub.com/deshamonisricharan/skill_3.git
# %cd skill_3
# !ls -la
# Out:
# Cloning into 'skill_3'...
# ...
# /content/skill_3
# total 12
# drwxr-xr-x 3 root root 4096 Aug  7 07:11 .
# drwxr-xr-x 1 root root 4096 Aug  7 07:11 ..
# drwxr-xr-x 7 root root 4096 Aug  7 07:11 .git

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
iris.data, iris.target, test_size=0.2, random_state=42
)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
pred = model.predict(X_test)
acc = accuracy_score(y_test, pred)
print("Accuracy:", acc)
# Out:
# Accuracy: 1.0

# %%
import dagshub
import mlflow
dagshub.init(
repo_owner="deshamonisricharan",
repo_name="skill_3",
mlflow=True
)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=5fd0e130-f79d-4bd1-91d3-c3dcbf67db16&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=cc3ea65100911098102acbf0e3d893708489020c11f285fd3dd5c0b564ef26af
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as deshamonisricharan
# Initialized MLflow to track repo "deshamonisricharan/skill_3"
# Repository deshamonisricharan/skill_3 initialized!

# %%
with mlflow.start_run():
  mlflow.log_param("n_estimators", 100)
  mlflow.log_metric("accuracy", acc)
  mlflow.sklearn.log_model(model, "random_forest_model")
  with open("result.txt", "w") as f:
    f.write(f"Accuracy: {acc}")
  mlflow.log_artifact("result.txt")
print("Experiment logged successfully")
# Out:
# 2026/08/07 06:47:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run bright-hawk-155 at: https://dagshub.com/deshamonisricharan/skill_3.mlflow/#/experiments/0/runs/328b8ba6bb1d4669bdd4f8aa6ef824bf
# 🧪 View experiment at: https://dagshub.com/deshamonisricharan/skill_3.mlflow/#/experiments/0
# Experiment logged successfully

# %%
print(mlflow.get_tracking_uri())
# Out:
# https://dagshub.com/deshamonisricharan/skill_3.mlflow

# %%
import mlflow
import dagshub
dagshub.init(
  repo_owner="deshamonisricharan",
  repo_name="skill_3",
  mlflow=True
)
mlflow.set_experiment("MLOps_Skill_3")
with mlflow.start_run():
  mlflow.log_param("model", "RandomForest")
  mlflow.log_param("n_estimators", 100)
  mlflow.log_metric("accuracy", 0.95)
  mlflow.log_metric("f1_score", 0.94)
  mlflow.sklearn.log_model(model, "model")
# Out:
# Initialized MLflow to track repo "deshamonisricharan/skill_3"
# Repository deshamonisricharan/skill_3 initialized!
# 2026/08/07 06:50:55 INFO mlflow.tracking.fluent: Experiment with name 'MLOps_Skill_3' does not exist. Creating a new experiment.
# 2026/08/07 06:50:56 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run amazing-snipe-934 at: https://dagshub.com/deshamonisricharan/skill_3.mlflow/#/experiments/1/runs/bc141d80c332469690e5927e93b03a66
# 🧪 View experiment at: https://dagshub.com/deshamonisricharan/skill_3.mlflow/#/experiments/1

# %%
# !mkdir outputs
# !cp result.txt outputs/

# %%
# !git add .
# !git commit -m "Added MLflow experiment and outputs"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !cp /content/result.txt .
# !cp -r /content/outputs .

# %%
# !ls
# Out:
# outputs  result.txt

# %%
# !git add .
# !git commit -m "Added MLflow experiment and outputs"
# Out:
# [main (root-commit) 357f01d] Added MLflow experiment and outputs
#  2 files changed, 2 insertions(+)
#  create mode 100644 outputs/result.txt
#  create mode 100644 result.txt

# %%
# !git branch
# Out:
# * main

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (4/4), 337 bytes | 337.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://dagshub.com/deshamonisricharan/skill_3.git
#  * [new branch]      main -> main

# %%
# !ls
# !git status
# Out:
# outputs  result.txt
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
